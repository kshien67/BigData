# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Convert categorical columns to 'category' dtype
sales_data['Product Category'] = sales_data['Product Category'].astype('category')
sales_data['City'] = sales_data['City'].astype('category')
sales_data['Time of Day'] = sales_data['Time of Day'].astype('category')

# Filter the dataset for 'Monitors' in the 'Product Category' column
monitors_data = sales_data[sales_data['Product Category'] == 'Monitors']

# Function to plot pie chart
def plot_pie_chart(column_name, data):
    value_counts = data[column_name].value_counts()
    plt.figure(figsize=(8, 6))
    plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title(f'Distribution of {column_name} (Monitors Only)')
    plt.axis('equal')
    plt.show()

# Plot pie charts for 'City' and 'Time of Day' for 'Monitors' category
plot_pie_chart('City', monitors_data)
plot_pie_chart('Time of Day', monitors_data)

# %%
import pandas as pd

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Convert categorical columns to 'category' dtype
sales_data['Product Category'] = sales_data['Product Category'].astype('category')
sales_data['City'] = sales_data['City'].astype('category')
sales_data['Time of Day'] = sales_data['Time of Day'].astype('category')

# Check the data types after conversion
sales_data.dtypes
# Out:
# Unnamed: 0                   int64
# Order ID                     int64
# Product Category          category
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int64
# Sales                      float64
# City                      category
# Hour                         int64
# Time of Day               category
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Convert categorical columns to 'category' dtype
sales_data['Product Category'] = sales_data['Product Category'].astype('category')
sales_data['City'] = sales_data['City'].astype('category')
sales_data['Time of Day'] = sales_data['Time of Day'].astype('category')

# Group data by 'Product Category' and sum the 'Sales'
sales_by_category = sales_data.groupby('Product Category')['Sales'].sum().sort_values(ascending=False)

# Generate a bar chart
plt.figure(figsize=(10, 6))
sales_by_category.plot(kind='bar', color='skyblue')
plt.title('Total Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20500\2301499756.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales_by_category = sales_data.groupby('Product Category')['Sales'].sum().sort_values(ascending=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Plotting histogram for 'Sales'
plt.figure(figsize=(10, 6))
plt.hist(sales_data['Sales'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Sales')
plt.xlabel('Sales Amount ($)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Group by 'Order Date' and sum 'Sales' to get the total sales per day
sales_by_date = sales_data.groupby('Order Date')['Sales'].sum()

# Plotting line chart for 'Sales' over time
plt.figure(figsize=(10, 6))
plt.plot(sales_by_date.index, sales_by_date, color='skyblue', marker='o', linestyle='-', linewidth=2)
plt.title('Sales Over Time')
plt.xlabel('Order Date')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Aggregate sales by month
sales_data['Month'] = sales_data['Order Date'].dt.to_period('M')  # Extract month and year
sales_by_month = sales_data.groupby('Month')['Sales'].sum()

# Plotting line chart for 'Sales' by month
plt.figure(figsize=(10, 6))
plt.plot(sales_by_month.index.astype(str), sales_by_month, color='skyblue', marker='o', linestyle='-', linewidth=2)
plt.title('Sales Over Time (Monthly)')
plt.xlabel('Order Date (Month)')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# List of numerical columns to plot
numerical_columns = ['Sales', 'Quantity Ordered', 'Price Each']

# Plot histograms for each numerical attribute
plt.figure(figsize=(14, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)  # 2x2 grid of subplots
    plt.hist(sales_data[column], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# List of numerical columns for box plots
numerical_columns = ['Sales', 'Quantity Ordered', 'Price Each']

# Plotting box plots for each numerical attribute
plt.figure(figsize=(14, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)  # 2x2 grid of subplots
    plt.boxplot(sales_data[column], patch_artist=True, boxprops=dict(facecolor='skyblue', color='black'))
    plt.title(f'Box Plot of {column}')
    plt.ylabel(column)
    plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# List of numerical columns for box plots
numerical_columns = ['Sales', 'Quantity Ordered', 'Price Each']

# Plotting box plots for each numerical attribute
plt.figure(figsize=(14, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)  # 2x2 grid of subplots
    plt.boxplot(sales_data[column], patch_artist=True, boxprops=dict(facecolor='skyblue', color='black'))
    plt.title(f'Box Plot of {column}')
    plt.ylabel(column)
    plt.ylim(0, sales_data[column].quantile(0.95))  # Limit the y-axis to 95th percentile for better clarity
    plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Function to filter out outliers using the IQR method
def filter_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# List of numerical columns for box plots
numerical_columns = ['Sales', 'Quantity Ordered', 'Price Each']

# Plotting box plots for each numerical attribute
plt.figure(figsize=(14, 10))
for i, column in enumerate(numerical_columns, 1):
    filtered_data = filter_outliers(sales_data, column)  # Filter out outliers using IQR
    plt.subplot(2, 2, i)  # 2x2 grid of subplots
    plt.boxplot(filtered_data[column], patch_artist=True, boxprops=dict(facecolor='skyblue', color='black'))
    plt.title(f'Box Plot of {column}')
    plt.ylabel(column)
    plt.tight_layout()

plt.show()

# %%
import pandas as pd

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# List of numerical columns
numerical_columns = ['Sales', 'Quantity Ordered', 'Price Each']

# Calculate summary statistics for each numerical attribute
summary_stats = sales_data[numerical_columns].describe().T

# Add mean, median, min, max, and std deviation to the table
summary_stats['mean'] = summary_stats['mean']
summary_stats['median'] = sales_data[numerical_columns].median()
summary_stats['min'] = summary_stats['min']
summary_stats['max'] = summary_stats['max']
summary_stats['std'] = summary_stats['std']

# Display the summary statistics
import ace_tools as tools; tools.display_dataframe_to_user(name="Summary Statistics", dataframe=summary_stats)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 24
#      21 summary_stats['std'] = summary_stats['std']
#      23 # Display the summary statistics
# ---> 24 import ace_tools as tools; tools.display_dataframe_to_user(name="Summary Statistics", dataframe=summary_stats)
#
# ModuleNotFoundError: No module named 'ace_tools'

# %%
import pandas as pd

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# List of numerical columns
numerical_columns = ['Sales', 'Quantity Ordered', 'Price Each']

# Calculate summary statistics for each numerical attribute
summary_stats = sales_data[numerical_columns].describe().T

# Add mean, median, min, max, and std deviation to the table
summary_stats['mean'] = summary_stats['mean']
summary_stats['median'] = sales_data[numerical_columns].median()
summary_stats['min'] = summary_stats['min']
summary_stats['max'] = summary_stats['max']
summary_stats['std'] = summary_stats['std']

# Display the summary statistics in the notebook
summary_stats
# Out:
#                      count        mean         std   min    25%    50%    75%  \
# Sales             185950.0  185.490917  332.919771  2.99  11.95  14.95  150.0
# Quantity Ordered  185950.0    1.124383    0.442793  1.00   1.00   1.00    1.0
# Price Each        185950.0  184.399735  332.731330  2.99  11.95  14.95  150.0
#
#                      max  median
# Sales             3400.0   14.95
# Quantity Ordered     9.0    1.00
# Price Each        1700.0   14.95

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# List of categorical columns
categorical_columns = ['Product Category', 'City', 'Time of Day']

# Plotting bar charts for each categorical attribute
plt.figure(figsize=(14, 10))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)  # 2x2 grid of subplots
    sales_data[column].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title(f'Bar Chart of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)
    plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# List of categorical columns for pie charts
categorical_columns = ['Product Category', 'City', 'Time of Day']

# Plotting pie charts for each categorical attribute
plt.figure(figsize=(14, 10))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)  # 2x2 grid of subplots
    sales_data[column].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, color=plt.cm.Paired.colors)
    plt.title(f'Pie Chart of {column}')
    plt.ylabel('')  # Hide the y-axis label
    plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Aggregate sales by month
sales_data['Month'] = sales_data['Order Date'].dt.to_period('M')  # Extract month and year
monthly_sales = sales_data.groupby('Month')['Sales'].sum()

# Plotting the line graph for 'Sales' over time
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales.index.astype(str), monthly_sales, marker='o', color='skyblue', linestyle='-', linewidth=2)
plt.title('Sales Amount Over Time')
plt.xlabel('Month')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Group data by 'Product Category' and sum the 'Sales'
sales_by_category = sales_data.groupby('Product Category')['Sales'].sum().sort_values(ascending=False)

# Plotting bar chart for Product Category vs Sales Amount
plt.figure(figsize=(12, 6))
sales_by_category.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Sales Amount by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plotting a pie chart for Customer Segment distribution
plt.figure(figsize=(8, 6))
sales_data['Customer Segment'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, color=plt.cm.Paired.colors)
plt.title('Distribution of Customer Segments')
plt.ylabel('')  # Hide the y-axis label
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer Segment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Plotting a pie chart for Customer Segment distribution
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/ASUS/Documents/Schoo/big data/Sales Data.csv"
sales_data = pd.read_csv(file_path)

# Convert 'Order Date' to datetime
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], format='%d-%m-%Y %H:%M')

# Plotting a pie chart for Customer Segment distribution
plt.figure(figsize=(8, 6))
sales_data['Customer Segment'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, color=plt.cm.Paired.colors)
plt.title('Distribution of Customer Segments')
plt.ylabel('')  # Hide the y-axis label
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer Segment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 13
#      11 # Plotting a pie chart for Customer Segment distribution
# ...

# %%
# Plotting a bar chart for sales by region
plt.figure(figsize=(12, 6))
sales_data.groupby('City')['Sales'].sum().sort_values(ascending=False).plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Sales Amount by Region (City)')
plt.xlabel('City')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
